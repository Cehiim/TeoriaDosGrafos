# %% [markdown]
# O pacote VectorDB2 é uma biblioteca leve em Python para armazenar e recuperar texto usando técnicas de fragmentação, incorporação e busca por vetores. Ele oferece uma interface fácil de usar para salvar, pesquisar e gerenciar dados textuais com metadados associados.

# %%
# %pip install vectordb2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 54.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# O LangChain é uma estrutura de orquestração de código aberto para o desenvolvimento de aplicativos com grandes modelos de linguagem (LLMs). Ele atua como uma interface genérica para praticamente qualquer LLM, proporcionando um ambiente centralizado para construir aplicativos LLM e integrá-los a fontes de dados externas e fluxos de trabalho de software.

# %%
# %pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 36.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.2/290.2 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# Aqui é importado o documento-fonte em formato Markdown, que foi segmentado através de seções para facilitar o processo de chunking.

# %%
import requests

raw_text = requests.get('https://raw.githubusercontent.com/Cehiim/TeoriaDosGrafos/refs/heads/main/Projeto/palavras.md').text

# %% [markdown]
# Aqui é definido o modelo de segmentação das informações do documento e através do framework LangChain foi feito o processo de chunking.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter()
texts = text_splitter.create_documents([raw_text])

# %% [markdown]
# Aqui é utilizado a biblioteca VectorDB para criar uma memória virtual.
#
# - chunking_strategy: Este parâmetro define a estratégia de fragmentação dos dados. No caso, estamos usando a estratégia de janela deslizante ("sliding_window"). Isso significa que os dados serão divididos em pedaços (chunks) de tamanho fixo, especificado pelo parâmetro window_size.
#
# - window_size: O tamanho dos chunks é definido como 1.
#
# - overlap: O valor de sobreposição (overlap) é 0. Isso indica quantos elementos de sobreposição existirão entre os chunks adjacentes.

# %%
from vectordb import Memory

memory = Memory(chunking_strategy={"mode": "sliding_window", "window_size": 1, "overlap": 0})
# Out:
# Initiliazing embeddings:  normal
# OK.

# %%
for i in range(0, len(texts)):
  texto = texts[i].page_content
  memory.save(texto)

# %%
vetor_texto = raw_text.split("\n")

# %% [markdown]
# Quanto menor é a distância, maior é a proximidade semântica.

# %%
for i in range(50):
  print(f"\n\nBusca: {vetor_texto[i]}\n")
  buscas = memory.search(vetor_texto[i], top_n=6)

  for j in range(1,6):
    palavra = buscas[j]['chunk']
    distancia = buscas[j]['distance']
    print(f"Palavra: {palavra}\nDistância: {distancia:.2f}\n")
# Out:
# Busca: 6
#
# Palavra: 6
# Distância: 0.00
#
# Palavra: 6
# Distância: 0.00
#
# Palavra: 6
# Distância: 0.00
#
# Palavra: 6
# Distância: 0.00
#
# Palavra: 6
# Distância: 0.00
#
#
#
# Busca: 50
#
# Palavra: 0.50
# Distância: 0.41
#
# Palavra: 48
# Distância: 0.44
#
# Palavra: 48
# Distância: 0.44
#
# Palavra: 48
# Distância: 0.44
#
# Palavra: 48
# Distância: 0.44
#
#
#
# Busca: 0 "seletiva"
#
# Palavra: 0.04
# Distância: 0.55
#
# Palavra: 0.04
# Distância: 0.55
#
# Palavra: 0.10
# Distância: 0.56
#
# Palavra: 0.60
# Distância: 0.57
#
# Palavra: 0.60
# Distância: 0.57
#
#
#
# Busca: 1 "controle"
#
# Palavra: 1
# Distância: 0.49
#
# Palavra: 1
# Distância: 0.49
#
# Palavra: 1
# Distância: 0.49
#
# Palavra: 1
# Distância: 0.49
#
# Palavra: 1
# Distância: 0.49
#
#
#
# Busca: 2 "clima"
#
# Palavra: 2
# Distância: 0.53
#
# Palavra: 2
# Distância: 0.53
#
# Palavra: 2
# Distância: 0.53
#
# Palavra: 2
# Distância: 0.53
#
# Palavra: "resíduos"
# Distância: 0.65
#
#
#
# Busca: 3 "ambiental"
#
# ...
